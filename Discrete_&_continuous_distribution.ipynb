# %% [markdown]
# ## Funciones de distribución discreta y continua

# %%
import scipy.stats
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from scipy.stats import binom


p = 0.3
n = 8 

x = list(range(0,9,1))
y = list([])

for i in x:
    y.append(binom.pmf(i, p=p, n=n))

fig, ax = plt.subplots()
ax.bar(x,y)
ax.set_ylabel('Probabilidad discreta')

np.sum(y)
# Out:
# 1.0

# %%
media = np.average(x, weights=y)
varianza = np.average(((x-media)**2), weights=y)

media, varianza
# Out:
# (2.3999999999999995, 1.6799999999999997)

# %%
fig, ax = plt.subplots()
ax.bar(x,y)
ax.set_ylabel('Probabilidad discreta')
ax.axvline(x=media, c='red', linestyle='--', label='Valor Esperado')
ax.axvline(x=media + 3*np.sqrt(varianza), c='red', linestyle='--', label='Desviación Estandar')
ax.legend()

# %%
N = 10000

x = list(range(0,N+1,1,))
y = list([])

for i in x:
    y.append(binom.cdf(i, p=0.3, n=N))
    
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Probabilidad Continua')
# Out:
# Text(0.5, 1.0, 'Probabilidad Continua')

# %%
from scipy.stats import norm
mean, var, skew, kurt = norm.stats(moments='mvsk')
print(mean)
print(var)
# Out:
# 0.0
# 1.0

# %% [markdown]
# ## Distribuciones de mayor aplicación discretas

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from scipy.stats import bernoulli
p = 0.3
data = bernoulli.rvs(p, size=100)
len(data)
# Out:
# 100

# %%
mean, var, skev, kurt = bernoulli.stats(p, moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(0.3), array(0.21), array(0.87287156), array(-1.23809524))

# %%
import seaborn as sns

#original: sns.distplot
#But it is replace for displot or histplot
ax = sns.histplot(data, bins=30, kde=False, color='blue')
ax.set(xlabel = 'Distribucion Bernoulli', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media')
ax.legend()

# %%
from scipy.stats import binom
p = 0.3
n = 10
data = binom.rvs(p=p,n=n, size=100)

mean, var, skev, kurt = binom.stats(p=p, n=n, moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(3.), array(2.1), array(0.27602622), array(-0.12380952))

# %%
import seaborn as sns

ax = sns.histplot(data, bins=30, kde=False, color='#537ac2')
ax.set(xlabel = 'Distribucion Binomial', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media', color='blue')
ax.legend()

# %%
from scipy.stats import nbinom
p = 0.3
n = 10
data = nbinom.rvs(p=p,n=n, size=100)

mean, var, skev, kurt = binom.stats(p=p, n=n, moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(3.), array(2.1), array(0.27602622), array(-0.12380952))

# %%
import seaborn as sns

ax = sns.histplot(data, bins=30, kde=False, color='#537ac2')
ax.set(xlabel = 'Distribucion Binomial Negativa', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media', color='blue')
ax.legend()

# %%
from scipy.stats import poisson
lambda_p = 100
data = poisson.rvs(mu=lambda_p, size=100)

mean, var, skev, kurt = poisson.stats(mu=lambda_p, moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(100.), array(100.), array(0.1), array(0.01))

# %%
import seaborn as sns

ax = sns.histplot(data, bins=30, kde=False, color='#537ac2')
ax.set(xlabel = 'Distribucion Poisson', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media', color='blue')
ax.legend()

# %% [markdown]
# ## Distribuciones de mayor aplicación continuas

# %%
from scipy.stats import expon
data = expon.rvs( size=10000000)

mean, var, skev, kurt = expon.stats(moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(1.), array(1.), array(2.), array(6.))

# %%
import seaborn as sns

ax = sns.histplot(data, bins=500, kde=False, color='#537ac2')
ax.set(xlabel = 'Distribucion Exponencial', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media', color='blue')
ax.legend()

# %%
from scipy.stats import norm
mean = 0
var = 1
data = norm.rvs( size=10000000)

mean, var, skev, kurt = norm.stats(moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(0.), array(1.), array(0.), array(0.))

# %%
import seaborn as sns

ax = sns.histplot(data, bins=500, kde=False, color='#537ac2')
ax.set(xlabel = 'Distribucion Normal Estandar', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media', color='blue')
ax.legend()

# %%
from scipy.stats import uniform
data = uniform.rvs( size=10000000)

mean, var, skev, kurt = uniform.stats(moments='mvsk')
mean, var, skev, kurt
# Out:
# (array(0.5), array(0.08333333), array(0.), array(-1.2))

# %%
import seaborn as sns

ax = sns.histplot(data, bins=500, kde=False, color='#537ac2')
ax.set(xlabel = 'Distribucion Uniforme 0 - 1', ylabel = 'Frecuencia')
ax.axvline(x=mean, linestyle='--', label='Media', color='blue')
ax.legend()
